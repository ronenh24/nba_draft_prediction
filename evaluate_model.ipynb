# %%
import pandas as pd
import numpy as np
from transformers import LongformerModel, AutoTokenizer
import torch
import lightgbm
import multiprocessing
import os
from tqdm import tqdm
# Out:
# C:\Users\chess\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\utils\generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# C:\Users\chess\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\utils\generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
def relevance_score(pick: int):
    if pick == -1:
        return 0
    return abs(pick - 61) / 6

# %%
def ndcg(predicted: list[float], actual: list[float], picks: int = 60):
    predicted = list(predicted)
    actual = list(actual)
    if picks > len(predicted):
        picks = len(predicted)
    dcg = 0
    idcg = 0
    for pick in range(1, picks + 1):
        dcg += predicted[pick - 1] / np.log2(pick + 1)
        idcg += actual[pick - 1] / np.log2(pick + 1)
    return dcg / idcg

# %%
def num_aspects(report: str) -> int:
    parts = report.split("…")
    num_parts = 0
    for part in parts:
        if part.strip() != "":
            num_parts += 1
    return num_parts

# %% [markdown]
# # Model

# %%
class L2RFeatureExtractor():
    def __init__(self):
        self.longformer_model = LongformerModel.from_pretrained("allenai/longformer-base-4096")
        self.longformer_tokenizer = AutoTokenizer.from_pretrained("allenai/longformer-base-4096")
    
    def get_height(self, height: int):
        return height
    
    def get_weight(self, weight: int):
        return weight
    
    def get_age(self, age: float):
        return age
    
    def get_strengths(self, strengths: str):
        return self.longformer_model(
            torch.tensor(self.longformer_tokenizer.encode(strengths)
        ).unsqueeze(0)).pooler_output[0, :].tolist()
    
    def get_weaknesses(self, weaknesses: str):
        return self.longformer_model(
            torch.tensor(self.longformer_tokenizer.encode(weaknesses)
        ).unsqueeze(0)).pooler_output[0, :].tolist()
    
    def get_features(self, strengths: str, weaknesses: str, height: int, weight: int, age: float):
        features = []

        features.append(self.get_height(height))
        features.append(self.get_weight(weight))
        features.append(self.get_age(age))

        features.extend(self.get_strengths(strengths))
        features.extend(self.get_weaknesses(weaknesses))

        return features

# %%
class L2RRanker:
    def __init__(self, feature_extractor: 'L2RFeatureExtractor',
                 lgbmranker_params: dict | None = None) -> None:
        self.feature_extractor = feature_extractor
        initial_lgbmranker_params = {'num_leaves': 10, 'learning_rate': 0.005, 'n_estimators': 50,
                                     'n_jobs': multiprocessing.cpu_count(), 'importance_type': 'gain',
                                     'metric': 'ndcg', 'verbosity': 1, 'label_gain': [2**i for i in range(0, 61)]}
        if lgbmranker_params:
            initial_lgbmranker_params.update(lgbmranker_params)
        self.lightgbm_ranker = lightgbm.LGBMRanker().set_params(**initial_lgbmranker_params)
    
    def train(self, train_draft_data: list[str]):
        train_features = []
        train_relevance_scores = []
        train_num_draft_examples = []

        for draft_year in train_draft_data:
            draft_df = pd.read_csv(draft_year)
            draft_df = draft_df.fillna("")
            draft_df["Relevance"] = draft_df["Pick"].apply(relevance_score)
            train_num_draft_examples.append(draft_df.shape[0])
            for name, _, strengths, weaknesses, height, weight, age, rel in tqdm(draft_df.itertuples(index = False, name = None)):
                for name_part in name.split():
                    strengths = strengths.replace(name_part, "")
                    weaknesses = weaknesses.replace(name_part, "")
                train_features.append(self.feature_extractor.get_features(strengths, weaknesses, height, weight, age))
                train_relevance_scores.append(int(rel * 6))
        
        self.lightgbm_ranker.fit(train_features, train_relevance_scores, group = train_num_draft_examples)
    
    def predict(self, test_draft_data: str):
        test_features = []

        draft_df = pd.read_csv(test_draft_data)
        draft_df = draft_df.fillna("")
        draft_df["Relevance"] = draft_df["Pick"].apply(relevance_score)
        for name, _, strengths, weaknesses, height, weight, age, _ in tqdm(draft_df.itertuples(index = False, name = None)):
            for name_part in name.split():
                strengths = strengths.replace(name_part, "")
                weaknesses = weaknesses.replace(name_part, "")
            test_features.append(self.feature_extractor.get_features(strengths, weaknesses, height, weight, age))
        
        return draft_df.iloc[list(np.argsort(self.lightgbm_ranker.predict(test_features))[::-1])]

# %%
l2r_feature_extractor = L2RFeatureExtractor()
l2r_ranker = L2RRanker(l2r_feature_extractor)

# %%
l2r_ranker.train(["data/2009_nba_draft_prospects.csv", 
                  "data/2010_nba_draft_prospects.csv",
                  "data/2011_nba_draft_prospects.csv",
                  "data/2012_nba_draft_prospects.csv",
                  "data/2013_nba_draft_prospects.csv",
                  "data/2014_nba_draft_prospects.csv",
                  "data/2015_nba_draft_prospects.csv",
                  "data/2016_nba_draft_prospects.csv",
                  "data/2017_nba_draft_prospects.csv",
                  "data/2018_nba_draft_prospects.csv",
                  "data/2019_nba_draft_prospects.csv"])
# Out:
# 103it [07:37,  4.44s/it]
# 103it [07:34,  4.41s/it]
# 107it [07:59,  4.48s/it]
# 102it [07:44,  4.55s/it]
# 101it [07:37,  4.53s/it]
# 104it [07:49,  4.51s/it]
# 102it [08:05,  4.76s/it]
# 102it [07:57,  4.68s/it]
# 100it [08:50,  5.30s/it]
# 101it [07:56,  4.72s/it]
# 102it [07:57,  4.68s/it]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.098619 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391503
# [LightGBM] [Info] Number of data points in the train set: 1127, number of used features: 1539

# %% [markdown]
# # 2020

# %%
draft_2020_df = pd.read_csv("data/2020_nba_draft_prospects.csv")
draft_2020_df = draft_2020_df.fillna("")
draft_2020_df[:14]
# Out:
#                  Name  Pick  \
# 0     Anthony Edwards     1
# 1       James Wiseman     2
# 2         LaMelo Ball     3
# 3    Patrick Williams     4
# 4         Isaac Okoro     5
# 5      Onyeka Okongwu     6
# 6       Killian Hayes     7
# 7          Obi Toppin     8
# 8         Deni Avdija     9
# 9         Jalen Smith    10
# 10      Devin Vassell    11
# 11  Tyrese Haliburton    12
# 12         Kira Lewis    13
# 13      Aaron Nesmith    14
#
#                                             Strengths  \
# 0   A rangy, 6’5 225 guard prospect with a truly f...
# 1   Wiseman has physical tools that really stand o...
# 2   A physically gifted lead guard prospect with p...
# 3   An explosive, “freakish” combo forward with in...
# 4   Fits the prototype physically of an NBA small ...
# 5   Exceptional rim protector who can block shots ...
# 6   Tall, left handed point guard (6-5), with very...
# 7   Toppin is a late blooming frontcourt prospect ...
# 8   All around talented wing with great size … Ver...
# 9   A long, versatile power forward with solid all...
# 10  One of the most athletic wings in this year’s ...
# 11  A tall and rangy PG, is a legitimate 6’5 and h...
# 12  Long, quick, athletic point guard with good sc...
# 13  A pure shooter who put up incredible stats for...
#
#                                            Weaknesses  Height  Weight    Age
# 0   Edwards has to improve his assertiveness on bo...      77     225  19.30
# 1   The obvious elephant in the room is that he go...      85     235  19.65
# 2   His overall jump shot lacks any real consisten...      78     180  19.25
# 3   There are question marks about his want to as ...      79     215  19.24
# 4   Okoro is a work in progress when it comes to h...      78     215  19.82
# 5   Must polish his offensive game as he can at ti...      81     235  19.95
# 6   Good, but not an elite athlete … Lacks an expl...      77     195  19.33
# 7   Though a standout athlete with nice size, Topp...      81     220  22.73
# 8   Has a below average wingspan (6-9) for his siz...      81     210  19.89
# 9   While he is bouncy, he is not the most fluid o...      82     220  20.69
# 10  Can improve on his ability to create offense f...      79     200  20.25
# 11  The main question about Haliburton is his narr...      77     185  20.73
# 12  Can improve in his ability to score from the p...      75     170  19.63
# 13  Body of work is not robust as he did not susta...      78     215  21.11

# %%
draft_2020_df["Relevance"] = draft_2020_df["Pick"].apply(relevance_score)
draft_2020_df[:14]
# Out:
#                  Name  Pick  \
# 0     Anthony Edwards     1
# 1       James Wiseman     2
# 2         LaMelo Ball     3
# 3    Patrick Williams     4
# 4         Isaac Okoro     5
# 5      Onyeka Okongwu     6
# 6       Killian Hayes     7
# 7          Obi Toppin     8
# 8         Deni Avdija     9
# 9         Jalen Smith    10
# 10      Devin Vassell    11
# 11  Tyrese Haliburton    12
# 12         Kira Lewis    13
# 13      Aaron Nesmith    14
#
#                                             Strengths  \
# 0   A rangy, 6’5 225 guard prospect with a truly f...
# 1   Wiseman has physical tools that really stand o...
# 2   A physically gifted lead guard prospect with p...
# 3   An explosive, “freakish” combo forward with in...
# 4   Fits the prototype physically of an NBA small ...
# 5   Exceptional rim protector who can block shots ...
# 6   Tall, left handed point guard (6-5), with very...
# 7   Toppin is a late blooming frontcourt prospect ...
# 8   All around talented wing with great size … Ver...
# 9   A long, versatile power forward with solid all...
# 10  One of the most athletic wings in this year’s ...
# 11  A tall and rangy PG, is a legitimate 6’5 and h...
# 12  Long, quick, athletic point guard with good sc...
# 13  A pure shooter who put up incredible stats for...
#
#                                            Weaknesses  Height  Weight    Age  \
# 0   Edwards has to improve his assertiveness on bo...      77     225  19.30
# 1   The obvious elephant in the room is that he go...      85     235  19.65
# 2   His overall jump shot lacks any real consisten...      78     180  19.25
# 3   There are question marks about his want to as ...      79     215  19.24
# 4   Okoro is a work in progress when it comes to h...      78     215  19.82
# 5   Must polish his offensive game as he can at ti...      81     235  19.95
# 6   Good, but not an elite athlete … Lacks an expl...      77     195  19.33
# 7   Though a standout athlete with nice size, Topp...      81     220  22.73
# 8   Has a below average wingspan (6-9) for his siz...      81     210  19.89
# 9   While he is bouncy, he is not the most fluid o...      82     220  20.69
# 10  Can improve on his ability to create offense f...      79     200  20.25
# 11  The main question about Haliburton is his narr...      77     185  20.73
# 12  Can improve in his ability to score from the p...      75     170  19.63
# 13  Body of work is not robust as he did not susta...      78     215  21.11
#
#     Relevance
# 0   10.000000
# 1    9.833333
# 2    9.666667
# 3    9.500000
# 4    9.333333
# 5    9.166667
# 6    9.000000
# 7    8.833333
# 8    8.666667
# 9    8.500000
# 10   8.333333
# 11   8.166667
# 12   8.000000
# 13   7.833333

# %% [markdown]
# ## First Baseline

# %%
draft_2020_df_first_baseline = draft_2020_df.sort_values(["Age", "Height"], ascending = [True, False])
draft_2020_df_first_baseline[:14]
# Out:
#                   Name  Pick  \
# 16  Aleksej Pokusevski    17
# 3     Patrick Williams     4
# 85     Malcolm Cazalon    -1
# 2          LaMelo Ball     3
# 0      Anthony Edwards     1
# 6        Killian Hayes     7
# 33        Theo Maledon    34
# 42      Jahmius Ramsey    43
# 15      Isaiah Stewart    16
# 12          Kira Lewis    13
# 1        James Wiseman     2
# 47        Nico Mannion    48
# 31        Vernon Carey    32
# 23          RJ Hampton    24
#
#                                             Strengths  \
# 16  Versatile forward with a guard skill set … Exc...
# 3   An explosive, “freakish” combo forward with in...
# 85  Athletic, lefty, guard/forward … Nice, wide sh...
# 2   A physically gifted lead guard prospect with p...
# 0   A rangy, 6’5 225 guard prospect with a truly f...
# 6   Tall, left handed point guard (6-5), with very...
# 33  Smart point guard with great size for his posi...
# 42  A mature, tough nosed freshman combo with intr...
# 15  Rugged big man with a tireless motor and youth...
# 12  Long, quick, athletic point guard with good sc...
# 1   Wiseman has physical tools that really stand o...
# 47  Mannion is a crafty 6’3 guard who has a nice b...
# 31  Steady, smooth bigman with scoring ability and...
# 23  A wiry 6’4 guard (6’7 wingspan) with intriguin...
#
#                                            Weaknesses  Height  Weight    Age  \
# 16  Has a really thin frame … Narrow shoulders, ma...      84     190  18.91
# 3   There are question marks about his want to as ...      79     215  19.24
# 85  Has a thin frame, he needs to bulk up his uppe...      78     185  19.24
# 2   His overall jump shot lacks any real consisten...      78     180  19.25
# 0   Edwards has to improve his assertiveness on bo...      77     225  19.30
# 6   Good, but not an elite athlete … Lacks an expl...      77     195  19.33
# 33  Not an overwhelming athlete but solid and uses...      77     185  19.45
# 42  Undersized at the 2G position at 6’4  … More o...      76     195  19.46
# 15  Below the rim athlete … Very long with decent ...      80     245  19.51
# 12  Can improve in his ability to score from the p...      75     170  19.63
# 1   The obvious elephant in the room is that he go...      85     235  19.65
# 47  Though on the surface Mannion’s prospect check...      75     190  19.70
# 31  Lacks elite speed and athleticism … Lack of fo...      82     270  19.74
# 23  Shows raw fundamentals and polish in general o...      76     175  19.79
#
#     Relevance
# 16   7.333333
# 3    9.500000
# 85   0.000000
# 2    9.666667
# 0   10.000000
# 6    9.000000
# 33   4.500000
# 42   3.000000
# 15   7.500000
# 12   8.000000
# 1    9.833333
# 47   2.166667
# 31   4.833333
# 23   6.166667

# %%
ndcg(draft_2020_df_first_baseline["Relevance"], draft_2020_df["Relevance"])
# Out:
# 0.8086882425729351

# %%
ndcg(draft_2020_df_first_baseline["Relevance"], draft_2020_df["Relevance"], 30)
# Out:
# 0.751018618741818

# %%
ndcg(draft_2020_df_first_baseline["Relevance"], draft_2020_df["Relevance"], 14)
# Out:
# 0.733230940213838

# %% [markdown]
# ## Second Baseline

# %%
draft_2020_df_second_baseline = draft_2020_df
draft_2020_df_second_baseline["Number_Strengths"] = draft_2020_df_second_baseline["Strengths"].apply(num_aspects)
draft_2020_df_second_baseline["Number_Weaknesses"] = draft_2020_df_second_baseline["Weaknesses"].apply(num_aspects)
draft_2020_df_second_baseline["Net_Strengths"] = draft_2020_df_second_baseline["Number_Strengths"] - draft_2020_df_second_baseline["Number_Weaknesses"]
draft_2020_df_second_baseline = draft_2020_df_second_baseline.sort_values(["Net_Strengths", "Number_Strengths", "Number_Weaknesses"], ascending = [False, False, True])
draft_2020_df_second_baseline[:14]
# Out:
#                 Name  Pick                                          Strengths  \
# 30      Tyrell Terry    31  Sharp shooting point guard with a slight frame...
# 31      Vernon Carey    32  Steady, smooth bigman with scoring ability and...
# 38     Elijah Hughes    39  Hughes is a smooth athlete with nice explosive...
# 22   Leandro Bolmaro    23  Versatile guard, who can be used in every peri...
# 43   Marko Simonovic    44  Fluid 7-footer, with acceptable level of athle...
# 33      Theo Maledon    34  Smart point guard with great size for his posi...
# 63  Abdoulaye N'Doye    -1  Versatile combo guard, with length, who can pl...
# 2        LaMelo Ball     3  A physically gifted lead guard prospect with p...
# 12        Kira Lewis    13  Long, quick, athletic point guard with good sc...
# 56      Reggie Perry    57  Physical specimen type of athlete with great f...
# 46         Yam Madar    47  Scrappy, ultra competitive and gritty point gu...
# 7         Obi Toppin     8  Toppin is a late blooming frontcourt prospect ...
# 60      Devon Dotson    -1  A speedster at the point guard position capabl...
# 42    Jahmius Ramsey    43  A mature, tough nosed freshman combo with intr...
#
#                                            Weaknesses  Height  Weight    Age  \
# 30  At just 160 lbs, he has extremely thin legs an...      75     170  20.15
# 31  Lacks elite speed and athleticism … Lack of fo...      82     270  19.74
# 38  Lacks ideal height for the wing position … Ath...      78     230  22.71
# 22  He looks longer than he actually is, since he ...      78     180  20.20
# 43  Decent athlete, but not overly athletic by NBA...      84     215  21.11
# 33  Not an overwhelming athlete but solid and uses...      77     185  19.45
# 63  Late bloomer and is shown at times, he is stil...      79     200  22.71
# 2   His overall jump shot lacks any real consisten...      78     180  19.25
# 12  Can improve in his ability to score from the p...      75     170  19.63
# 56  Not a big shot blocker or rim protector … All ...      81     250  20.68
# 46  He is a just above average athlete by NBA stan...      75     180  19.92
# 7   Though a standout athlete with nice size, Topp...      81     220  22.73
# 60  Small for an NBA point guard with a sub 8 foot...      74     185  21.31
# 42  Undersized at the 2G position at 6’4  … More o...      76     195  19.46
#
#     Relevance  Number_Strengths  Number_Weaknesses  Net_Strengths
# 30   5.000000                30                 13             17
# 31   4.833333                27                 11             16
# 38   3.666667                23                  8             15
# 22   6.333333                32                 18             14
# 43   2.833333                34                 21             13
# 33   4.500000                32                 19             13
# 63   0.000000                30                 17             13
# 2    9.666667                25                 12             13
# 12   8.000000                24                 11             13
# 56   0.666667                21                  8             13
# 46   2.333333                26                 15             11
# 7    8.833333                19                  9             10
# 60   0.000000                18                  8             10
# 42   3.000000                21                 12              9

# %%
ndcg(draft_2020_df_second_baseline["Relevance"], draft_2020_df["Relevance"])
# Out:
# 0.7273686948784405

# %%
ndcg(draft_2020_df_second_baseline["Relevance"], draft_2020_df["Relevance"], 30)
# Out:
# 0.5506800651555249

# %%
ndcg(draft_2020_df_second_baseline["Relevance"], draft_2020_df["Relevance"], 14)
# Out:
# 0.48093486939349095

# %% [markdown]
# ## L2R Model

# %%
draft_2020_df_model = l2r_ranker.predict("data/2020_nba_draft_prospects.csv")
draft_2020_df_model[:14]
# Out:
# 0it [00:00, ?it/s]
# 103it [07:55,  4.62s/it]
#                 Name  Pick                                          Strengths  \
# 12        Kira Lewis    13  Long, quick, athletic point guard with good sc...
# 3   Patrick Williams     4  An explosive, “freakish” combo forward with in...
# 2        LaMelo Ball     3  A physically gifted lead guard prospect with p...
# 47      Nico Mannion    48  Mannion is a crafty 6’3 guard who has a nice b...
# 10     Devin Vassell    11  One of the most athletic wings in this year’s ...
# 1      James Wiseman     2  Wiseman has physical tools that really stand o...
# 23        RJ Hampton    24  A wiry 6’4 guard (6’7 wingspan) with intriguin...
# 8        Deni Avdija     9  All around talented wing with great size … Ver...
# 0    Anthony Edwards     1  A rangy, 6’5 225 guard prospect with a truly f...
# 86    Khalil Whitney    -1  6’6 athletic forward … Good size and length wi...
# 5     Onyeka Okongwu     6  Exceptional rim protector who can block shots ...
# 54        Jay Scrubb    55  6’6 left-handed scoring guard … Good length wi...
# 30      Tyrell Terry    31  Sharp shooting point guard with a slight frame...
# 31      Vernon Carey    32  Steady, smooth bigman with scoring ability and...
#
#                                            Weaknesses  Height  Weight    Age  \
# 12  Can improve in his ability to score from the p...      75     170  19.63
# 3   There are question marks about his want to as ...      79     215  19.24
# 2   His overall jump shot lacks any real consisten...      78     180  19.25
# 47  Though on the surface Mannion’s prospect check...      75     190  19.70
# 10  Can improve on his ability to create offense f...      79     200  20.25
# 1   The obvious elephant in the room is that he go...      85     235  19.65
# 23  Shows raw fundamentals and polish in general o...      76     175  19.79
# 8   Has a below average wingspan (6-9) for his siz...      81     210  19.89
# 0   Edwards has to improve his assertiveness on bo...      77     225  19.30
# 86  Can get stronger in both the upper and lower b...      79     205  19.87
# 5   Must polish his offensive game as he can at ti...      81     235  19.95
# 54  Although he showed progression in the second h...      78     185  20.23
# 30  At just 160 lbs, he has extremely thin legs an...      75     170  20.15
# 31  Lacks elite speed and athleticism … Lack of fo...      82     270  19.74
#
#     Relevance
# 12   8.000000
# 3    9.500000
# 2    9.666667
# 47   2.166667
# 10   8.333333
# 1    9.833333
# 23   6.166667
# 8    8.666667
# 0   10.000000
# 86   0.000000
# 5    9.166667
# 54   1.000000
# 30   5.000000
# 31   4.833333

# %%
ndcg(draft_2020_df_model["Relevance"], draft_2020_df["Relevance"])
# Out:
# 0.8240587421324435

# %%
ndcg(draft_2020_df_model["Relevance"], draft_2020_df["Relevance"], 30)
# Out:
# 0.76354467406514

# %%
ndcg(draft_2020_df_model["Relevance"], draft_2020_df["Relevance"], 14)
# Out:
# 0.7702542208425405

# %% [markdown]
# # 2021

# %%
draft_2021_df = pd.read_csv("data/2021_nba_draft_prospects.csv")
draft_2021_df = draft_2021_df.fillna("")
draft_2021_df[:14]
# Out:
#                 Name  Pick                                          Strengths  \
# 0    Cade Cunningham     1  A prized 6’8 220+ lb lead guard prospect who h...
# 1        Jalen Green     2  Green is a high upside prospect with elite ath...
# 2        Evan Mobley     3  Mobley has a chance to be a generational bigma...
# 3     Scottie Barnes     4  Versatility and power are the two greatest str...
# 4        Jalen Suggs     5  Lead guard with great leadership, toughness an...
# 5        Josh Giddey     6  Natural talented point guard with great size …...
# 6   Jonathan Kuminga     7  Listed at 6’7 and 220 pounds, Kuminga is a phy...
# 7       Franz Wagner     8  Wagner has ideal size and versatility for a mo...
# 8    Davion Mitchell     9  Mitchell is an incredibly efficient scorer, wi...
# 9    Ziaire Williams    10  High level athlete who uses his size and verti...
# 10   James Bouknight    11  Athletic slasher who is one of the best pure s...
# 11      Joshua Primo    12  A lean 6’5 wing who possesses solid physical a...
# 12      Chris Duarte    13  Gifted and natural scorer … Scored over 17 poi...
# 13       Moses Moody    14  Good size for a wing with a frame that should ...
#
#                                            Weaknesses  Height  Weight    Age
# 0   While he is a physically gifted prospect, Cunn...      80     220  19.85
# 1   Green is a good shooter, but is not yet a snip...      77     180  19.48
# 2   The biggest hurdle for Evan Mobley is himself....      84     215  20.13
# 3   The biggest thing holding Barnes back from a h...      80     225  20.01
# 4   The most glaring weakness for the star freshma...      76     205  20.17
# 5   Average athlete… Has a really thin frame, and ...      80     205  18.81
# 6   Lacks consistency shooting … Kuminga is an inc...      79     220  18.82
# 7   Wagner may struggle to create his own shot in ...      82     220  19.93
# 8   Needs to improve as a pick and roll facilitato...      73     200  22.91
# 9   Williams struggled to stay on the court for th...      81     190  19.89
# 10  Athleticism is better in half court, somewhat ...      77     190  20.87
# 11  Not a particularly explosive athlete, doesn’t ...      77     190  18.61
# 12  At 23 years old, Duarte’s most glaring weaknes...      78     190  24.14
# 13  Doesn’t play with speed/enough athleticism to ...      78     210  19.18

# %%
draft_2021_df["Relevance"] = draft_2021_df["Pick"].apply(relevance_score)
draft_2021_df[:14]
# Out:
#                 Name  Pick                                          Strengths  \
# 0    Cade Cunningham     1  A prized 6’8 220+ lb lead guard prospect who h...
# 1        Jalen Green     2  Green is a high upside prospect with elite ath...
# 2        Evan Mobley     3  Mobley has a chance to be a generational bigma...
# 3     Scottie Barnes     4  Versatility and power are the two greatest str...
# 4        Jalen Suggs     5  Lead guard with great leadership, toughness an...
# 5        Josh Giddey     6  Natural talented point guard with great size …...
# 6   Jonathan Kuminga     7  Listed at 6’7 and 220 pounds, Kuminga is a phy...
# 7       Franz Wagner     8  Wagner has ideal size and versatility for a mo...
# 8    Davion Mitchell     9  Mitchell is an incredibly efficient scorer, wi...
# 9    Ziaire Williams    10  High level athlete who uses his size and verti...
# 10   James Bouknight    11  Athletic slasher who is one of the best pure s...
# 11      Joshua Primo    12  A lean 6’5 wing who possesses solid physical a...
# 12      Chris Duarte    13  Gifted and natural scorer … Scored over 17 poi...
# 13       Moses Moody    14  Good size for a wing with a frame that should ...
#
#                                            Weaknesses  Height  Weight    Age  \
# 0   While he is a physically gifted prospect, Cunn...      80     220  19.85
# 1   Green is a good shooter, but is not yet a snip...      77     180  19.48
# 2   The biggest hurdle for Evan Mobley is himself....      84     215  20.13
# 3   The biggest thing holding Barnes back from a h...      80     225  20.01
# 4   The most glaring weakness for the star freshma...      76     205  20.17
# 5   Average athlete… Has a really thin frame, and ...      80     205  18.81
# 6   Lacks consistency shooting … Kuminga is an inc...      79     220  18.82
# 7   Wagner may struggle to create his own shot in ...      82     220  19.93
# 8   Needs to improve as a pick and roll facilitato...      73     200  22.91
# 9   Williams struggled to stay on the court for th...      81     190  19.89
# 10  Athleticism is better in half court, somewhat ...      77     190  20.87
# 11  Not a particularly explosive athlete, doesn’t ...      77     190  18.61
# 12  At 23 years old, Duarte’s most glaring weaknes...      78     190  24.14
# 13  Doesn’t play with speed/enough athleticism to ...      78     210  19.18
#
#     Relevance
# 0   10.000000
# 1    9.833333
# 2    9.666667
# 3    9.500000
# 4    9.333333
# 5    9.166667
# 6    9.000000
# 7    8.833333
# 8    8.666667
# 9    8.500000
# 10   8.333333
# 11   8.166667
# 12   8.000000
# 13   7.833333

# %% [markdown]
# ## First Baseline

# %%
draft_2021_df_first_baseline = draft_2021_df.sort_values(["Age", "Height"], ascending = [True, False])
draft_2021_df_first_baseline[:14]
# Out:
#                 Name  Pick                                          Strengths  \
# 11      Joshua Primo    12  A lean 6’5 wing who possesses solid physical a...
# 5        Josh Giddey     6  Natural talented point guard with great size …...
# 6   Jonathan Kuminga     7  Listed at 6’7 and 220 pounds, Kuminga is a phy...
# 27    Jaden Springer    28  Scrappy, young combo guard with a defensive fo...
# 36           JT Thor    37  A very rangy 6’10 stretch four, who has genera...
# 44    Juhann Begarin    45  Athletic combo guard with good size … Versatil...
# 15    Alperen Sengun    16  Physical center, with a lot of determination a...
# 13       Moses Moody    14  Good size for a wing with a frame that should ...
# 22      Usman Garuba    23  Blue collar forward/center, who always gives 1...
# 20      Keon Johnson    21  A freakish athlete with great mental make up a...
# 63       Daishen Nix    -1  Nix was surrounded by other five-star prospect...
# 1        Jalen Green     2  Green is a high upside prospect with elite ath...
# 21    Isaiah Jackson    22  Extremely athletic, agile big man that can imp...
# 19     Jalen Johnson    20  Athletic and versatile point forward with an e...
#
#                                            Weaknesses  Height  Weight    Age  \
# 11  Not a particularly explosive athlete, doesn’t ...      77     190  18.61
# 5   Average athlete… Has a really thin frame, and ...      80     205  18.81
# 6   Lacks consistency shooting … Kuminga is an inc...      79     220  18.82
# 27  Lacks elite explosiveness … Appears to be more...      76     200  18.85
# 36  Has one of the most impressive highlight reels...      82     205  18.94
# 44  Inconsistent … Kind of raw, his game needs pol...      78     215  18.99
# 15  Average athlete by NBA standards … Small for a...      81     240  19.02
# 13  Doesn’t play with speed/enough athleticism to ...      78     210  19.18
# 22  He is more a 5 than a 4 for now on offense bec...      80     230  19.40
# 20  A work in progress offensively. Shot only 27% ...      77     185  19.40
# 63  With a ghastly three-point percentage of 17%, ...      76     225  19.47
# 1   Green is a good shooter, but is not yet a snip...      77     180  19.48
# 21  At this point he is viewed as a project for th...      82     205  19.56
# 19  Three-point shooting has the potential to be a...      81     210  19.62
#
#     Relevance
# 11   8.166667
# 5    9.166667
# 6    9.000000
# 27   5.500000
# 36   4.000000
# 44   2.666667
# 15   7.500000
# 13   7.833333
# 22   6.333333
# 20   6.666667
# 63   0.000000
# 1    9.833333
# 21   6.500000
# 19   6.833333

# %%
ndcg(draft_2021_df_first_baseline["Relevance"], draft_2021_df["Relevance"])
# Out:
# 0.7996542223484874

# %%
ndcg(draft_2021_df_first_baseline["Relevance"], draft_2021_df["Relevance"], 30)
# Out:
# 0.738268226677913

# %%
ndcg(draft_2021_df_first_baseline["Relevance"], draft_2021_df["Relevance"], 14)
# Out:
# 0.7424909106667161

# %% [markdown]
# ## Second Baseline

# %%
draft_2021_df_second_baseline = draft_2021_df
draft_2021_df_second_baseline["Number_Strengths"] = draft_2021_df_second_baseline["Strengths"].apply(num_aspects)
draft_2021_df_second_baseline["Number_Weaknesses"] = draft_2021_df_second_baseline["Weaknesses"].apply(num_aspects)
draft_2021_df_second_baseline["Net_Strengths"] = draft_2021_df_second_baseline["Number_Strengths"] - draft_2021_df_second_baseline["Number_Weaknesses"]
draft_2021_df_second_baseline = draft_2021_df_second_baseline.sort_values(["Net_Strengths", "Number_Strengths", "Number_Weaknesses"], ascending = [False, False, True])
draft_2021_df_second_baseline[:14]
# Out:
#                Name  Pick                                          Strengths  \
# 0   Cade Cunningham     1  A prized 6’8 220+ lb lead guard prospect who h...
# 22     Usman Garuba    23  Blue collar forward/center, who always gives 1...
# 8   Davion Mitchell     9  Mitchell is an incredibly efficient scorer, wi...
# 12     Chris Duarte    13  Gifted and natural scorer … Scored over 17 poi...
# 14    Corey Kispert    15  Mature, focused four year college player with ...
# 1       Jalen Green     2  Green is a high upside prospect with elite ath...
# 3    Scottie Barnes     4  Versatility and power are the two greatest str...
# 7      Franz Wagner     8  Wagner has ideal size and versatility for a mo...
# 18        Kai Jones    19  Jones is an explosive athlete who plays with o...
# 15   Alperen Sengun    16  Physical center, with a lot of determination a...
# 25  Nah'Shon Hyland    26  Talented scorer, averaging 19.5 points per gam...
# 4       Jalen Suggs     5  Lead guard with great leadership, toughness an...
# 65           EJ Onu    -1  Onu is an athletic, stretch-five big man who i...
# 51       Luka Garza    52  A decorated winner and athlete at Iowa for fou...
#
#                                            Weaknesses  Height  Weight    Age  \
# 0   While he is a physically gifted prospect, Cunn...      80     220  19.85
# 22  He is more a 5 than a 4 for now on offense bec...      80     230  19.40
# 8   Needs to improve as a pick and roll facilitato...      73     200  22.91
# 12  At 23 years old, Duarte’s most glaring weaknes...      78     190  24.14
# 14  May take some time to adjust to the quickness ...      79     225  22.42
# 1   Green is a good shooter, but is not yet a snip...      77     180  19.48
# 3   The biggest thing holding Barnes back from a h...      80     225  20.01
# 7   Wagner may struggle to create his own shot in ...      82     220  19.93
# 18  Jones stands at 6’11 but at 220 lbs, currently...      83     220  20.54
# 15  Average athlete by NBA standards … Small for a...      81     240  19.02
# 25  With a shift to more position-less basketball ...      75     170  20.88
# 4   The most glaring weakness for the star freshma...      76     205  20.17
# 65  Played in the NAIA, which does not possess the...      83     240  22.01
# 51  Garza is one of the older players in this draf...      83     245  22.60
#
#     Relevance  Number_Strengths  Number_Weaknesses  Net_Strengths
# 0   10.000000                22                  8             14
# 22   6.333333                29                 16             13
# 8    8.666667                25                 12             13
# 12   8.000000                19                  6             13
# 14   7.666667                23                 11             12
# 1    9.833333                20                  8             12
# 3    9.500000                18                  6             12
# 7    8.833333                22                 11             11
# 18   7.000000                18                  7             11
# 15   7.500000                29                 19             10
# 25   5.833333                21                 11             10
# 4    9.333333                20                 10             10
# 65   0.000000                15                  5             10
# 51   1.500000                13                  3             10

# %%
ndcg(draft_2021_df_second_baseline["Relevance"], draft_2021_df["Relevance"])
# Out:
# 0.8322794754578953

# %%
ndcg(draft_2021_df_second_baseline["Relevance"], draft_2021_df["Relevance"], 30)
# Out:
# 0.7572219418526501

# %%
ndcg(draft_2021_df_second_baseline["Relevance"], draft_2021_df["Relevance"], 14)
# Out:
# 0.8351294763835987

# %% [markdown]
# ## L2R Model

# %%
draft_2021_df_model = l2r_ranker.predict("data/2021_nba_draft_prospects.csv")
draft_2021_df_model[:14]
# Out:
# 0it [00:00, ?it/s]
# 102it [07:50,  4.61s/it]
#                 Name  Pick                                          Strengths  \
# 20      Keon Johnson    21  A freakish athlete with great mental make up a...
# 47    Sharife Cooper    48  A highly talented, creative lead guard prospec...
# 2        Evan Mobley     3  Mobley has a chance to be a generational bigma...
# 26    Cameron Thomas    27  A 6’3 200 lb perimeter scoring machine (4th in...
# 42        Greg Brown    43  Brown is a freak athlete with a great deal of ...
# 6   Jonathan Kuminga     7  Listed at 6’7 and 220 pounds, Kuminga is a phy...
# 9    Ziaire Williams    10  High level athlete who uses his size and verti...
# 15    Alperen Sengun    16  Physical center, with a lot of determination a...
# 4        Jalen Suggs     5  Lead guard with great leadership, toughness an...
# 11      Joshua Primo    12  A lean 6’5 wing who possesses solid physical a...
# 3     Scottie Barnes     4  Versatility and power are the two greatest str...
# 23  Josh Christopher    24  A top shelf athlete who showcases the power an...
# 1        Jalen Green     2  Green is a high upside prospect with elite ath...
# 28    Day'Ron Sharpe    29  A true throwback big man, Sharpe is the best r...
#
#                                            Weaknesses  Height  Weight    Age  \
# 20  A work in progress offensively. Shot only 27% ...      77     185  19.40
# 47  Generously listed at 6’1 165, and without much...      73     180  20.15
# 2   The biggest hurdle for Evan Mobley is himself....      84     215  20.13
# 26  A bit one-dimensional as a player, mostly wire...      75     200  19.81
# 42  Needs to become a better overall offensive pla...      80     205  19.92
# 6   Lacks consistency shooting … Kuminga is an inc...      79     220  18.82
# 9   Williams struggled to stay on the court for th...      81     190  19.89
# 15  Average athlete by NBA standards … Small for a...      81     240  19.02
# 4   The most glaring weakness for the star freshma...      76     205  20.17
# 11  Not a particularly explosive athlete, doesn’t ...      77     190  18.61
# 3   The biggest thing holding Barnes back from a h...      80     225  20.01
# 23  While his three-point shooting improved toward...      76     215  19.65
# 1   Green is a good shooter, but is not yet a snip...      77     180  19.48
# 28  As the NBA has evolved into a pace and space l...      82     265  19.74
#
#     Relevance
# 20   6.666667
# 47   2.166667
# 2    9.666667
# 26   5.666667
# 42   3.000000
# 6    9.000000
# 9    8.500000
# 15   7.500000
# 4    9.333333
# 11   8.166667
# 3    9.500000
# 23   6.166667
# 1    9.833333
# 28   5.333333

# %%
ndcg(draft_2021_df_model["Relevance"], draft_2021_df["Relevance"])
# Out:
# 0.7715103330368926

# %%
ndcg(draft_2021_df_model["Relevance"], draft_2021_df["Relevance"], 30)
# Out:
# 0.7017883743969205

# %%
ndcg(draft_2021_df_model["Relevance"], draft_2021_df["Relevance"], 14)
# Out:
# 0.7439132287655769

# %% [markdown]
# # 2022

# %%
draft_2022_df = pd.read_csv("data/2022_nba_draft_prospects.csv")
draft_2022_df = draft_2022_df.fillna("")
draft_2022_df[:14]
# Out:
#                   Name  Pick  \
# 0       Paolo Banchero     1
# 1        Chet Holmgren     2
# 2         Jabari Smith     3
# 3        Keegan Murray     4
# 4           Jaden Ivey     5
# 5   Bennedict Mathurin     6
# 6       Shaedon Sharpe     7
# 7        Dyson Daniels     8
# 8        Jeremy Sochan     9
# 9         Johnny Davis    10
# 10       Ousmane Dieng    11
# 11      Jalen Williams    12
# 12         Jalen Duren    13
# 13        Ochai Agbaji    14
#
#                                             Strengths  \
# 0   Has good size and length for his position, sta...
# 1   Extremely skilled frontcourt player who can in...
# 2   Wiry 6’10 combo / stretch four with long arms ...
# 3   A 6’8 225 frontcourt player with the frame, le...
# 4   An aggressive explosive, 6’4 200 lb combo guar...
# 5   6’7 wing with tremendous size, maturity, explo...
# 6   An incredibly athletic wing who ranked as the ...
# 7   6-6 combo guard with great size and length for...
# 8   The less heralded freshman Baylor forward, Soc...
# 9   A 6’5 190 SG/SF with the athleticism and wiry ...
# 10  Versatile point forward … Possesses great size...
# 11  A bulky wing with a great frame (massive 7-2 w...
# 12  A physically gifted, highly touted 6’11 250 bi...
# 13  A lean, yet strong 6’6 215 wing who looks the ...
#
#                                            Weaknesses  Height  Weight    Age
# 0   For all of his offensive gifts, still has room...      82     250  19.62
# 1   Lack of physical strength (195 lbs) remains hi...      84     195  20.16
# 2   Rebounding numbers could stand some improvemen...      82     220  19.13
# 3   Will have some questions about his true positi...      80     225  21.86
# 4   Ivey’s hard charging energy and play style can...      76     195  20.37
# 5   The biggest hurdle for Mathurin at this point ...      78     205  20.02
# 6   Focus, intensity and maturity remain mysteries...      77     200  19.08
# 7   While his skill potential is high. Feel for th...      79     195  19.28
# 8   Most lottery picks have more scoring productio...      81     230  19.11
# 9   Was asked to be a go-to scorer last season out...      77     195  20.33
# 10  Has put on some weight, but he still has a thi...      81     185  19.10
# 11  Definitely has some burst, but not the elite a...      78     210  21.21
# 12  Motivation level is one of the key Duren is a ...      83     250  18.61
# 13  Not particularly creative or shifty as a ball-...      78     215  22.19

# %%
draft_2022_df["Relevance"] = draft_2022_df["Pick"].apply(relevance_score)
draft_2022_df[:14]
# Out:
#                   Name  Pick  \
# 0       Paolo Banchero     1
# 1        Chet Holmgren     2
# 2         Jabari Smith     3
# 3        Keegan Murray     4
# 4           Jaden Ivey     5
# 5   Bennedict Mathurin     6
# 6       Shaedon Sharpe     7
# 7        Dyson Daniels     8
# 8        Jeremy Sochan     9
# 9         Johnny Davis    10
# 10       Ousmane Dieng    11
# 11      Jalen Williams    12
# 12         Jalen Duren    13
# 13        Ochai Agbaji    14
#
#                                             Strengths  \
# 0   Has good size and length for his position, sta...
# 1   Extremely skilled frontcourt player who can in...
# 2   Wiry 6’10 combo / stretch four with long arms ...
# 3   A 6’8 225 frontcourt player with the frame, le...
# 4   An aggressive explosive, 6’4 200 lb combo guar...
# 5   6’7 wing with tremendous size, maturity, explo...
# 6   An incredibly athletic wing who ranked as the ...
# 7   6-6 combo guard with great size and length for...
# 8   The less heralded freshman Baylor forward, Soc...
# 9   A 6’5 190 SG/SF with the athleticism and wiry ...
# 10  Versatile point forward … Possesses great size...
# 11  A bulky wing with a great frame (massive 7-2 w...
# 12  A physically gifted, highly touted 6’11 250 bi...
# 13  A lean, yet strong 6’6 215 wing who looks the ...
#
#                                            Weaknesses  Height  Weight    Age  \
# 0   For all of his offensive gifts, still has room...      82     250  19.62
# 1   Lack of physical strength (195 lbs) remains hi...      84     195  20.16
# 2   Rebounding numbers could stand some improvemen...      82     220  19.13
# 3   Will have some questions about his true positi...      80     225  21.86
# 4   Ivey’s hard charging energy and play style can...      76     195  20.37
# 5   The biggest hurdle for Mathurin at this point ...      78     205  20.02
# 6   Focus, intensity and maturity remain mysteries...      77     200  19.08
# 7   While his skill potential is high. Feel for th...      79     195  19.28
# 8   Most lottery picks have more scoring productio...      81     230  19.11
# 9   Was asked to be a go-to scorer last season out...      77     195  20.33
# 10  Has put on some weight, but he still has a thi...      81     185  19.10
# 11  Definitely has some burst, but not the elite a...      78     210  21.21
# 12  Motivation level is one of the key Duren is a ...      83     250  18.61
# 13  Not particularly creative or shifty as a ball-...      78     215  22.19
#
#     Relevance
# 0   10.000000
# 1    9.833333
# 2    9.666667
# 3    9.500000
# 4    9.333333
# 5    9.166667
# 6    9.000000
# 7    8.833333
# 8    8.666667
# 9    8.500000
# 10   8.333333
# 11   8.166667
# 12   8.000000
# 13   7.833333

# %% [markdown]
# ## First Baseline

# %%
draft_2022_df_first_baseline = draft_2022_df.sort_values(["Age", "Height"], ascending = [True, False])
draft_2022_df_first_baseline[:14]
# Out:
#                Name  Pick                                          Strengths  \
# 67  Dominick Barlow    -1  A player with a high ceiling and good potentia...
# 12      Jalen Duren    13  A physically gifted, highly touted 6’11 250 bi...
# 53    Yannick Nzosa    54  Athletic, left handed center… Great size for h...
# 15       AJ Griffin    16  Prototypical size for an NBA wing at 6-6, 220 ...
# 41     Trevor Keels    42  A physical, imposing combo guard who gets to t...
# 43     Ryan Rollins    44  A smooth, talented ball-handler and initiator ...
# 62     Jean Montero    -1  A natural scorer, the Overtime Elite guard has...
# 26     Nikola Jovic    27  All around combo forward … Has point forward p...
# 6    Shaedon Sharpe     7  An incredibly athletic wing who ranked as the ...
# 10    Ousmane Dieng    11  Versatile point forward … Possesses great size...
# 8     Jeremy Sochan     9  The less heralded freshman Baylor forward, Soc...
# 2      Jabari Smith     3  Wiry 6’10 combo / stretch four with long arms ...
# 47    Kendall Brown    48  Brown pairs excellent size with top shelf athl...
# 19   Malaki Branham    20  An athletic three-level scorer who can create ...
#
#                                            Weaknesses  Height  Weight    Age  \
# 67  The NBA Draft Combine helped identify areas of...      82     220  18.46
# 12  Motivation level is one of the key Duren is a ...      83     250  18.61
# 53  Extremely thin frame… Needs to add considerabl...      83     200  18.62
# 15  Despite his great length and athleticism, lack...      78     220  18.84
# 41  Not really a great fit at either guard positio...      76     225  18.84
# 43  Rollins put up great numbers in two seasons fo...      75     180  18.99
# 62  Montero lacks standout length (6-2 with a 6-4 ...      74     170  18.99
# 26  Needs to add some weight … Despite his fightin...      83     225  19.05
# 6   Focus, intensity and maturity remain mysteries...      77     200  19.08
# 10  Has put on some weight, but he still has a thi...      81     185  19.10
# 8   Most lottery picks have more scoring productio...      81     230  19.11
# 2   Rebounding numbers could stand some improvemen...      82     220  19.13
# 47  Skill set in need of refining … Scored 9.7 poi...      79     200  19.13
# 19  Shoots smoothly as a spot-up shooter, but look...      77     195  19.13
#
#     Relevance
# 67   0.000000
# 12   8.000000
# 53   1.166667
# 15   7.500000
# 41   3.166667
# 43   2.833333
# 62   0.000000
# 26   5.666667
# 6    9.000000
# 10   8.333333
# 8    8.666667
# 2    9.666667
# 47   2.166667
# 19   6.833333

# %%
ndcg(draft_2022_df_first_baseline["Relevance"], draft_2022_df["Relevance"])
# Out:
# 0.6965407237920551

# %%
ndcg(draft_2022_df_first_baseline["Relevance"], draft_2022_df["Relevance"], 30)
# Out:
# 0.5105968016806653

# %%
ndcg(draft_2022_df_first_baseline["Relevance"], draft_2022_df["Relevance"], 14)
# Out:
# 0.4922581047707503

# %% [markdown]
# ## Second Baseline

# %%
draft_2022_df_second_baseline = draft_2022_df
draft_2022_df_second_baseline["Number_Strengths"] = draft_2022_df_second_baseline["Strengths"].apply(num_aspects)
draft_2022_df_second_baseline["Number_Weaknesses"] = draft_2022_df_second_baseline["Weaknesses"].apply(num_aspects)
draft_2022_df_second_baseline["Net_Strengths"] = draft_2022_df_second_baseline["Number_Strengths"] - draft_2022_df_second_baseline["Number_Weaknesses"]
draft_2022_df_second_baseline = draft_2022_df_second_baseline.sort_values(["Net_Strengths", "Number_Strengths", "Number_Weaknesses"], ascending = [False, False, True])
draft_2022_df_second_baseline[:14]
# Out:
#                 Name  Pick                                          Strengths  \
# 25     Wendell Moore    26  A skilled and physical slasher with terrific p...
# 2       Jabari Smith     3  Wiry 6’10 combo / stretch four with long arms ...
# 59    Ron Harper Jr.    -1  Bigtime college player who despite not passing...
# 71  Orlando Robinson    -1  Highly skilled bigman with great length and in...
# 0     Paolo Banchero     1  Has good size and length for his position, sta...
# 33   Jaylin Williams    34  A relentless, versatile center who is built fo...
# 43      Ryan Rollins    44  A smooth, talented ball-handler and initiator ...
# 49   Matteo Spagnolo    50  Naturally talented combo guard… Good size for ...
# 38      Khalifa Diop    39  Athletic, blue collar big… Has prototypical si...
# 14     Mark Williams    15  Developing center, rim runner, rim protector w...
# 45   Ismael Kamagate    46  Athletic big… Has good size for his position… ...
# 12       Jalen Duren    13  A physically gifted, highly touted 6’11 250 bi...
# 16        Tari Eason    17  Versatile, athletic forward that can play eith...
# 79  Trevion Williams    -1  A gifted and unique blend of scoring and playm...
#
#                                            Weaknesses  Height  Weight    Age  \
# 25  Really struggled in his first two seasons at D...      77     215  20.78
# 2   Rebounding numbers could stand some improvemen...      82     220  19.13
# 59  Clearly slow and unathletic from an NBA perspe...      77     240  22.21
# 71  Average athlete by NBA standards … Feet are a ...      83     245  21.97
# 0   For all of his offensive gifts, still has room...      82     250  19.62
# 33  Is comfortable shooting on the perimeter and h...      82     235  20.00
# 43  Rollins put up great numbers in two seasons fo...      75     180  18.99
# 49  Not a real point guard just yet… A little unde...      77     195  19.46
# 38  Not an elite athlete… Needs time to gather bef...      83     230  20.45
# 14  Yet to show that his range can expand to an NB...      85     240  20.53
# 45  Has a really thin frame for now, he needs to g...      83     230  21.44
# 12  Motivation level is one of the key Duren is a ...      83     250  18.61
# 16  Overall approach and game in need of refinemen...      80     215  21.13
# 79  Not very mobile defensively and could be taken...      80     265  21.78
#
#     Relevance  Number_Strengths  Number_Weaknesses  Net_Strengths
# 25   5.833333                24                  7             17
# 2    9.666667                23                 10             13
# 59   0.000000                22                 10             12
# 71   0.000000                20                  9             11
# 0   10.000000                18                  7             11
# 33   4.500000                17                  6             11
# 43   2.833333                17                  6             11
# 49   1.833333                27                 17             10
# 38   3.666667                26                 16             10
# 14   7.666667                17                  7             10
# 45   2.500000                26                 17              9
# 12   8.000000                18                  9              9
# 16   7.333333                17                  9              8
# 79   0.000000                15                  7              8

# %%
ndcg(draft_2022_df_second_baseline["Relevance"], draft_2022_df["Relevance"])
# Out:
# 0.6855341484639138

# %%
ndcg(draft_2022_df_second_baseline["Relevance"], draft_2022_df["Relevance"], 30)
# Out:
# 0.5754285124898122

# %%
ndcg(draft_2022_df_second_baseline["Relevance"], draft_2022_df["Relevance"], 14)
# Out:
# 0.5249416260241548

# %% [markdown]
# ## L2R Model

# %%
draft_2022_df_model = l2r_ranker.predict("data/2022_nba_draft_prospects.csv")
draft_2022_df_model[:14]
# Out:
# 0it [00:00, ?it/s]
# 102it [08:19,  4.90s/it]
#                   Name  Pick  \
# 24        Blake Wesley    25
# 60        Justin Lewis    -1
# 5   Bennedict Mathurin     6
# 29       Peyton Watson    30
# 19      Malaki Branham    20
# 36         Jaden Hardy    37
# 8        Jeremy Sochan     9
# 6       Shaedon Sharpe     7
# 12         Jalen Duren    13
# 58         John Butler    -1
# 38        Khalifa Diop    39
# 33     Jaylin Williams    34
# 52          JD Davison    53
# 2         Jabari Smith     3
#
#                                             Strengths  \
# 24  NBA athlete with a great deal of upside left t...
# 60  Great length for his position, has the power a...
# 5   6’7 wing with tremendous size, maturity, explo...
# 29  Highly rated recruit with a lot of upside but ...
# 19  An athletic three-level scorer who can create ...
# 36  A highly touted recruit who chose to play with...
# 8   The less heralded freshman Baylor forward, Soc...
# 6   An incredibly athletic wing who ranked as the ...
# 12  A physically gifted, highly touted 6’11 250 bi...
# 58  Upside, upside upside … Butler’s insane length...
# 38  Athletic, blue collar big… Has prototypical si...
# 33  A relentless, versatile center who is built fo...
# 52  A truly breathtaking athlete, Davison looks li...
# 2   Wiry 6’10 combo / stretch four with long arms ...
#
#                                            Weaknesses  Height  Weight    Age  \
# 24  Due to being an unheralded recruit, may take s...      76     185  19.28
# 60  Just 6’6.25″ barefoot but his 7’2″ wingspan ma...      79     235  20.21
# 5   The biggest hurdle for Mathurin at this point ...      78     205  20.02
# 29  Lack of readiness makes him a project for the ...      80     205  19.79
# 19  Shoots smoothly as a spot-up shooter, but look...      77     195  19.13
# 36  A disappointing season with the G-League Ignit...      76     200  19.98
# 8   Most lottery picks have more scoring productio...      81     230  19.11
# 6   Focus, intensity and maturity remain mysteries...      77     200  19.08
# 12  Motivation level is one of the key Duren is a ...      83     250  18.61
# 58  At just 174.4 lbs, Butler is rail thin and wil...      85     175  19.56
# 38  Not an elite athlete… Needs time to gather bef...      83     230  20.45
# 33  Is comfortable shooting on the perimeter and h...      82     235  20.00
# 52  Davison needs to develop a reliable outside sh...      74     190  19.73
# 2   Rebounding numbers could stand some improvemen...      82     220  19.13
#
#     Relevance
# 24   6.000000
# 60   0.000000
# 5    9.166667
# 29   5.166667
# 19   6.833333
# 36   4.000000
# 8    8.666667
# 6    9.000000
# 12   8.000000
# 58   0.000000
# 38   3.666667
# 33   4.500000
# 52   1.333333
# 2    9.666667

# %%
ndcg(draft_2022_df_model["Relevance"], draft_2022_df["Relevance"])
# Out:
# 0.7023395837786813

# %%
ndcg(draft_2022_df_model["Relevance"], draft_2022_df["Relevance"], 30)
# Out:
# 0.5957083791531073

# %%
ndcg(draft_2022_df_model["Relevance"], draft_2022_df["Relevance"], 14)
# Out:
# 0.5840653361201581
